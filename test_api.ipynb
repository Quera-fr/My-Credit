# %%
import requests

data = {
    "age": 30,
    "job": "admin.",
    "marital": "married",
    "education": "secondary",
    "default": "no",
    "housing": "yes",
    "balance": 5000.0,
    "previous": 2,
    "loan": "no",
    "contact": "cellular",
    "day": 15,
    "month": "may",
    "duration": 180,
    "campaign": 3,
    "pdays": 15,
    "poutcome": "success"
}
reponse = requests.get("http://127.0.0.1:8000/prediction", params=data)
print(reponse.text)
# Out:
# {"detail":[{"type":"missing","loc":["body"],"msg":"Field required","input":null,"url":"https://errors.pydantic.dev/2.4/v/missing"}]}

# %%
# reponse = requests.get("http://127.0.0.1:8000/d", params={"n":5})
reponse = requests.post("http://127.0.0.1:8000/di", json=data)

# %%
reponse.json()
# Out:
# 2.5

# %%
reponse = requests.post("http://127.0.0.1:8000/prediction", json={"n":5})

# %%
{"n":"o"}
